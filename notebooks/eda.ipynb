# %% [markdown]
# # EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# some_file.py
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '/home/slinde/Documents/Repos/Thesis/')

import src.data.data_generator as dg

sns.set()

# %%
df = dg.set_datetime_index(dg.load_dataset("/home/slinde/Documents/Repos/Thesis/data/raw/eth_dataset.parquet"))

# %%
df.head()
# Out:
#                       timestamp  Asset_ID  Count      Open    High     Low  \
# datetime
# 2018-01-01 00:01:00  1514764860         6  173.0  738.3025  746.00  732.51
# 2018-01-01 00:02:00  1514764920         6  192.0  738.5075  745.14  732.49
# 2018-01-01 00:03:00  1514764980         6  120.0  738.3325  745.12  730.00
# 2018-01-01 00:04:00  1514765040         6  156.0  737.2225  744.69  728.93
# 2018-01-01 00:05:00  1514765100         6  118.0  736.5300  743.80  727.11
#
#                         Close      Volume        VWAP    Target
# datetime
# 2018-01-01 00:01:00  738.5075  335.987856  738.839291 -0.004809
# 2018-01-01 00:02:00  738.2600  232.793141  738.268967 -0.004441
# 2018-01-01 00:03:00  737.5025  174.138031  737.994457 -0.004206
# 2018-01-01 00:04:00  737.1025  165.383926  737.303631 -0.002205
# 2018-01-01 00:05:00  735.7050  193.078039  736.163026 -0.001744

# %%
rv = dg.generate_realized_var(df['Close'], "daily")

# %%
rvm = dg.generate_realized_var(df['Close'], "monthly")

# %%
volume = dg.sum_period(df['Volume'], "daily")
volume_m = dg.sum_period(df['Volume'], "monthly")

# %%
rv
# Out:
# datetime
# 2018-01-02    0.016887
# 2018-01-03    0.007453
# 2018-01-04    0.000024
# 2018-01-05    0.000411
# 2018-01-06    0.001726
#                 ...
# 2021-09-17    0.002367
# 2021-09-18    0.000115
# 2021-09-19    0.001009
# 2021-09-20    0.012441
# 2021-09-21    0.000002
# Freq: D, Name: Close, Length: 1359, dtype: float64

# %%
plt.figure(figsize=(15, 8))
sns.lineplot(x=rv.index, y=rv.values)
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
plt.figure(figsize=(15, 8))
sns.lineplot(x=volume.index, y=volume.values)
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
plt.figure(figsize=(15, 8))
sns.lineplot(x=rvm.index, y=rvm.values)
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
plt.figure(figsize=(15, 8))
sns.lineplot(x=volume_m.index, y=volume_m.values)
# Out:
# <AxesSubplot:xlabel='datetime'>
